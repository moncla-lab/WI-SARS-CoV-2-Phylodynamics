# %%
import sys
import pandas as pd 
import numpy as np
import plotly.express as px


# Lambodhar Damodaran 2023 
# Script to standardize associated location metadata for sequences of SARS-COV-2 from Wisconsin downloaded from GISAID


data = input("Enter tsv file: ")
#df = pd.read_csv(data, sep='\t')
df = pd.read_csv("~/WI-COVID-to2023_04_15_dedup.tsv", sep='\t')


# urban = u , rural = r
county_u_r = {'adams' : 'r'
,'ashland' : 'r'
,'barron' : 'r'
,'bayfield' : 'r'
,'buffalo' : 'r'
,'burnett' : 'r'
,'clark' : 'r'
,'crawford' : 'r'
,'dodge' : 'r'
,'door' : 'r'
,'dunn' : 'r'
,'florence' : 'r'
,'forest' : 'r'
,'grant' : 'r'
,'green lake' : 'r'
,'iron' : 'r'
,'jackson' : 'r'
,'jefferson' : 'r'
,'juneau' : 'r'
,'lafayette' : 'r'
,'langlade' : 'r'
,'lincoln' : 'r'
,'manitowoc' : 'r'
,'marinette' : 'r'
,'marquette' : 'r'
,'menominee' : 'r'
,'monroe' : 'r'
,'oneida' : 'r'
,'pepin' : 'r'
,'polk' : 'r'
,'portage' : 'r'
,'price' : 'r'
,'richland' : 'r'
,'rusk' : 'r'
,'sauk' : 'r'
,'sawyer' : 'r'
,'shawano' : 'r'
,'taylor' : 'r'
,'trempealeau' : 'r'
,'vernon' : 'r'
,'vilas' : 'r'
,'walworth' : 'r'
,'washburn' : 'r'
,'waupaca' : 'r'
,'waushara' : 'r'
,'wood' : 'r'
,'brown' : 'u'
,'calumet' : 'u'
,'chippewa' : 'u'
,'columbia' : 'u'
,'dane' : 'u'
,'douglas' : 'u'
,'eau claire' : 'u'
,'fond du lac' : 'u'
,'green' : 'u'
,'iowa' : 'u'
,'kenosha' : 'u'
,'kewaunee' : 'u'
,'la crosse' : 'u'
,'marathon' : 'u'
,'milwaukee' : 'u'
,'oconto' : 'u'
,'outagamie' : 'u'
,'ozaukee' : 'u'
,'pierce' : 'u'
,'racine' : 'u'
,'rock' : 'u'
,'st croix' : 'u'
,'sheboygan' : 'u'
,'washington' : 'u'
,'waukesha' : 'u'
,'winnebago' : 'u' }

city_county = { 'madison' : 'dane',
               'east troy' : 'walworth',
               'greenfield' : 'milwaukee',
               'oregon' : 'dane',
               'hartland' : 'waukesha',
               'delavan' : 'walworth',
               'rhinelander' : 'oneida',
               'wisconsin rapids' : 'wood',
               'green bay' : 'brown',
               'clintonville' : 'waupaca',
               'lomira' : 'dodge',
               'endaevor' : 'marquette',
               'eagle' : 'waukesha',
               'brown deer' : 'milwaukee',
               'sheboygan falls' : 'sheboygan',
               'caledonia' : 'racine',
               'sherwood' : 'calumet',
               'slinger' : 'washington',
               'elm grove' : 'waukesha',
               'waterloo' : 'jefferson',
               'south milwaukee' : 'milwaukee',
               'elkhart lake' : 'sheboygan',
               'hubertus' : 'washington',
               'lake mills' : 'jefferson',
               'new berlin' : 'waukesha',
               'mosinee' : 'marathon',
               'stoughton' : 'dane',
               'twin lakes' : 'kenosha',
               'colgate' : 'washington',
               'cross plains' : 'dane',
               'pewaukee' : 'waukesha',
               'two rivers' : 'manitowoc',
               'cedarburg' : 'ozaukee',
               'sauk city' : 'sauk',
               'windsor' : 'dane',
               'viroqua' : 'vernon',
               'sharon' : 'walworth',
               'sun prairie' : 'dane',
               'wild rose' : 'waushara',
               'saint francis' : 'milwaukee',
               'salem' : 'kenosha',
               'elkhorn' : 'walworth',
               'columbus' : 'columbia',
               'edgerton' : 'rock',
               'hales corners' : 'milwaukee',
               'fitchburg' : 'dane',
               'milw' : 'milwaukee',
               'rosholt' : 'portage',
               'germantown' : 'washington',
               'baraboo' : 'sauk',
               'milton' : 'rock',
               'chippewa falls' : 'chippewa',
               'wisconsin dells' : 'sauk',
               'middleton' : 'dane',
               'new glarus' : 'green',
               'bristol' : 'kenosha',
               'superior' : 'douglas',
               'cudahy' : 'milwaukee',
               'brookfield' : 'waukesha',
               'port washington' : 'ozaukee',
               'thiensville' : 'ozaukee',
               'mequon' : 'ozaukee',
               'viola' : 'richland',
               'oak creek' : 'milwaukee',
               'sparta' : 'monroe',
               'little chute' : 'outagamie',
               'bloomer' : 'chippewa',
               'sturgeon bay' : 'door',
               'deforest' : 'dane',
               'poynette' : 'columbia',
               'mount pleasant' : 'racine',
               'maricopa' : 'winnebago',
               'orange' : 'juneau',
               'lacrosse' : 'la crosse',
               'lee' : 'oneida',
               'chilton' : 'calumet',
               'new holstein' : 'calumet',
               'eau clair' : 'eau claire',
               'menomonee falls' : 'waukesha',
               'ripon' : 'fond du lac',
               'st francis' : 'milwaukee',
               'stevens point' : 'portage',
               'oconomowoc' : 'waukesha',
               'kaukauna' : 'outagamie',
               'oshkosh' : 'winnebago',
               'hilbert' : 'calumet',
               'seymour' : 'outagamie',
               'waupun' : 'fond du lac',
               'lake geneva' : 'walworth',
               'black earth' : 'dane',
               'galesville' : 'trempealeau',
               'montello' : 'marquette',
               'minocqua' : 'oneida',
               'mukwonago' : 'waukesha',
               'tomah' : 'monroe',
               'bayside' : 'milwaukee',
               'genoa city' : 'kenosha',
               'pell lake' : 'walworth',
               'sussex' : 'waukesha',
               'eagle river' : 'vilas',
               'burlington' : 'racine',
               'janesville' : 'rock',
               'wausau' : 'marathon',
               'grafton' : 'ozaukee',
               'prairie du sac' : 'sauk',
               'beaver dam' : 'dodge',
               'mayville' : 'dodge',
               'grand chute' : 'outagamie',
               'holmen' : 'la crosse',
               'muskego' : 'waukesha',
               'wauwatosa' : 'milwaukee',
               'whitefish bay' : 'milwaukee',
               'franklin' : 'milwaukee',
               'watertown' : 'dodge',
               'west allis' : 'milwaukee',
               'shorewood' : 'milwaukee',
               'glendale' : 'milwaukee',
               'verona' : 'dane',
               'union grove' : 'racine',
               'sturtevant' : 'racine',
               'saint joseph' : 'st croix',
               'houlton' : 'st croix',
               'unknown' : '0',
               'mauston' : 'juneau',
               'west bend' : 'washington',
               'mcfarland' : 'dane',
               'plymouth' : 'sheboygan',
               'beloit' : 'rock',
               'wales' : 'waukesha',
               'neenah' : 'winnebago',
               'platteville' : 'grant',
               'appleton' : 'outagamie',
               'menasha' : 'calumet',
               'waunakee' : 'dane',

}

misseplled_county = {'st. croix' : 'st croix',
                     'saint croix' : 'st croix',
                     'outgamie' : 'outagamie',
                     'colombia' : 'columbia',
                     'evansville' : 'rock',
                     'gren lake' : 'green lake',
                     'waupeca' : 'waupaca',
                     'trempeleau' : 'trempealeau',
                     'waukeshacounty' : 'waukesha',
                     'fon du lac' : 'fond du lac',
                     'winnebgo' : 'winnebago',
                     'pine' : '0',
                     'chisago' : '0',
                     'onondaga' : '0',
                     'dickinson' : '0',
                     'ogle' : '0',
                     'champaign' : '0',
                     'mchenry' : '0',
                     
       
}

# Location notes: 
# St. Croix is entered as ST CROIX without . to avoid delimitor issues
# The city of WISCONSIN DELLS straddles 4 counties, Columbia,Sauk,Adams,Juneau

# Uncertain locations: PINE, DICKINSON
# A few entries may be for sequences actually from other states (ILLINOIS)
# Illinois: CHAMPAIGN, OGLE 
# Michigan: ONONDAGA
# Minnesota: CHISAGO
# for data filtering purposes these are filtered for county to be be NaN
# Out:
# Enter tsv file: j

# %%
df['County'] = df['Location'].str.lower()

# %%
df['County'] = df['County'].str.replace('north america / usa / wisconsin / ', '')
df['County'] = df['County'].str.replace('north america / usa / wisconsin', '')
df['County'] = df['County'].str.replace(' county', '')
df['County'] = df['County'].str.replace('county', '')



df = df.replace('', np.nan)
df = df.replace({"County" : city_county})
df = df.replace({"County" : misseplled_county})
df['County'] = df['County'].str.replace('0', '')
df = df.replace('', np.nan)

df['urban_rural'] = df['County']
df = df.replace({"urban_rural" : county_u_r})
df = df.query("County != 'lake'") # removing one seq with this county which doesnt exist and causing issues renameing other names with lake in them
df2 = df[df.County.notnull()]
df2.to_csv("WI-GISAID-county.tsv", sep = '\t')
