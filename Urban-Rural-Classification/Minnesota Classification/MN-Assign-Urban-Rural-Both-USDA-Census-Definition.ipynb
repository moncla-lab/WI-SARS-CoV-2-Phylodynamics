# %%
# This imports the Metadata
# I named the given test file "TEST-Official-Metadata-MN.csv" for an example
# Change the csv name to reflect what the metadate file is called
import pandas
df = pandas.read_csv('TEST-Official-Metadata-MN.csv',dtype=object)
import numpy as np  # Import numpy for NaN representation
df = df.replace(np.nan, '')

df
# Out:
#      case_id covid_mn_id                         covid_virus_name  \
# 0  555555555   MN8888888  hCoV-19/USA/MN-CDC-IBX############/YYYY
#
#          gisaid_id genbank_id ncbi_bioproject_id ncbi_biosample_id first_name  \
# 0  EPI_ISL_#######       test               test              test       test
#
#   last_name birth_date  ... adi_natrank adi_staternk           county    zip  \
# 0      test       test  ...          25            2  Hennepin County  55406
#
#    race raceth hispanic gender time_since age_group
# 0  test   test     test   test       test      test
#
# [1 rows x 27 columns]

# %%
# This creates a new column of assigned or unassigned USDA urban/rural classifications
# With the Wisconsin metadata, some samples did not have a Census Tract number, which is why this is necessary to show that some samples will remain unassigned
# Thus, this is not necessary if all your samples have a Census Tract Number
# This also provides clarification for the blank values
def assigned_or_unassigned(row):
    
    # This is testing the following: if census_tract is Nan; if not, there is a confirmed rural/urban classification
    if pandas.notna(row['census_tract']) and any(char.isdigit() for char in str(row['census_tract'])):
        print('Assigned')
        return 'Assigned'
    else:
        print('Unassigned')
        return 'Unassigned'

df['Assigned-or-Unassigned-USDA-Classification'] = df.apply(assigned_or_unassigned, axis=1)

df
# Out:
# Assigned
#      case_id covid_mn_id                         covid_virus_name  \
# 0  555555555   MN8888888  hCoV-19/USA/MN-CDC-IBX############/YYYY
#
#          gisaid_id genbank_id ncbi_bioproject_id ncbi_biosample_id first_name  \
# 0  EPI_ISL_#######       test               test              test       test
#
#   last_name birth_date  ... adi_staternk           county    zip  race raceth  \
# 0      test       test  ...            2  Hennepin County  55406  test   test
#
#   hispanic gender time_since age_group  \
# 0     test   test       test      test
#
#   Assigned-or-Unassigned-USDA-Classification
# 0                                   Assigned
#
# [1 rows x 28 columns]

# %%
# Here we read in the file from the USDA classification
# I titled the RUCA file as "MN-RUCA-Definitions"
ruca = pandas.read_csv('MN-RUCA-Definitions.csv',dtype=object)

ruca
# Out:
#      State-County FIPS Code Select State           Select County  \
# 0                     27001           MN           Aitkin County
# 1                     27001           MN           Aitkin County
# 2                     27001           MN           Aitkin County
# 3                     27001           MN           Aitkin County
# 4                     27001           MN           Aitkin County
# ...                     ...          ...                     ...
# 1333                  27171           MN           Wright County
# 1334                  27173           MN  Yellow Medicine County
# 1335                  27173           MN  Yellow Medicine County
# 1336                  27173           MN  Yellow Medicine County
# 1337                  27173           MN  Yellow Medicine County
#
#      Total-FIPS-Code Primary RUCA Code 2010  \
# 0        27001770100                     10
# 1        27001770200                     10
# 2        27001770300                     10
# 3        27001770400                     10
# 4        27001790501                     10
# ...              ...                    ...
# 1333     27171101300                      7
# 1334     27173970100                      7
# 1335     27173970200                     10
# 1336     27173970300                     10
# 1337     27173970400                     10
#
#      Secondary RUCA Code, 2010 (see errata) Tract Population, 2010  \
# 0                                        10                  2,327
# 1                                        10                  2,336
# 2                                        10                  3,268
# 3                                        10                  3,052
# 4                                        10                  1,957
# ...                                     ...                    ...
# 1333                                      7                  4,964
# 1334                                      7                  3,371
# 1335                                     10                  2,520
# 1336                                     10                  2,517
# 1337                                     10                  2,030
#
#      Land Area (square miles), 2010 Population Density (per square mile), 2010
# 0                             458.9                                        5.1
# 1                             461.8                                        5.1
# 2                              33.4                                       97.8
# 3                             460.1                                        6.6
# 4                             294.3                                        6.7
# ...                             ...                                        ...
# 1333                           69.1                                       71.9
# 1334                          147.5                                       22.9
# 1335                          144.1                                       17.5
# 1336                          286.3                                        8.8
# 1337                          181.2                                       11.2
#
# [1338 rows x 9 columns]

# %%
# Merge the data from both files
# We are matching the values from the 11 digit census_tract with the 11 digit Total-FIPS-Code from the USDA
# See the specified column names from the example in Git
usda_merged_df = pandas.merge(df, ruca, left_on='census_tract', right_on='Total-FIPS-Code', how='left')

# This prevents Unassigned values from being dropped
usda_merged_df.fillna(value={'column_name_in_ruca': 'Unassigned'}, inplace=True)

# This removes NaN values
usda_merged_df = usda_merged_df.replace(np.nan, '')

usda_merged_df
# Out:
#      case_id covid_mn_id                         covid_virus_name  \
# 0  555555555   MN8888888  hCoV-19/USA/MN-CDC-IBX############/YYYY
#
#          gisaid_id genbank_id ncbi_bioproject_id ncbi_biosample_id first_name  \
# 0  EPI_ISL_#######       test               test              test       test
#
#   last_name birth_date  ... Assigned-or-Unassigned-USDA-Classification  \
# 0      test       test  ...                                   Assigned
#
#   State-County FIPS Code Select State    Select County Total-FIPS-Code  \
# 0                  27053           MN  Hennepin County     27053106400
#
#   Primary RUCA Code 2010 Secondary RUCA Code, 2010 (see errata)  \
# 0                      1                                      1
#
#   Tract Population, 2010 Land Area (square miles), 2010  \
# 0                  1,821                            0.2
#
#   Population Density (per square mile), 2010
# 0                                   8,860.50
#
# [1 rows x 37 columns]

# %%
# This creates a new file that I titled "MN-Midwest-Sars-Cov-2-ASSIGNED-Metadata"
usda_merged_df.to_csv('MN-Midwest-Sars-Cov-2-ASSIGNED-Metadata.csv')

# %%
# This creates a new column that categorizes urban or rural based on USDA data
# The function also determines Urban or Rural classification
file_path = 'MN-Midwest-Sars-Cov-2-ASSIGNED-Metadata.csv'
df = pandas.read_csv(file_path)
def urban_or_rural_classification(row):
    primary_ruca_code = row['Primary RUCA Code 2010']
    
    if primary_ruca_code in [1, 2, 3, 4, 5, 6, 7,8]:
        return 'Urban'
    elif primary_ruca_code in [9, 10]:
        return 'Rural'
    else:
        return 'Unknown'

# Create the new column
df['Urban-or-Rural-USDA-Classification'] = df.apply(urban_or_rural_classification, axis=1)

#This removes NaN values
df = df.replace(np.nan, '')

# Save the modified DataFrame back to the CSV file
df.to_csv(file_path, index=False)

df
# Out:
#    Unnamed: 0    case_id covid_mn_id                         covid_virus_name  \
# 0           0  555555555   MN8888888  hCoV-19/USA/MN-CDC-IBX############/YYYY
#
#          gisaid_id genbank_id ncbi_bioproject_id ncbi_biosample_id first_name  \
# 0  EPI_ISL_#######       test               test              test       test
#
#   last_name  ... State-County FIPS Code Select State    Select County  \
# 0      test  ...                  27053           MN  Hennepin County
#
#    Total-FIPS-Code  Primary RUCA Code 2010  \
# 0      27053106400                       1
#
#    Secondary RUCA Code, 2010 (see errata) Tract Population, 2010  \
# 0                                       1                  1,821
#
#   Land Area (square miles), 2010  Population Density (per square mile), 2010  \
# 0                            0.2                                    8,860.50
#
#    Urban-or-Rural-USDA-Classification
# 0                               Urban
#
# [1 rows x 39 columns]

# %%
# Here we read in the file from the CENSUS classification
import pandas
census = pandas.read_csv('NHGIS-CensusTract-Data-MN.csv',dtype=object)

census
# Out:
#                   GISJOIN            YEAR                         GEOID  \
# 0     GIS Join Match Code  Data File Year  Geographic Record Identifier
# 1          G2700010770100            2020          1400000US27001770100
# 2          G2700010770200            2020          1400000US27001770200
# 3          G2700010770300            2020          1400000US27001770300
# 4          G2700010770401            2020          1400000US27001770401
# ...                   ...             ...                           ...
# 1501       G2701710101300            2020          1400000US27171101300
# 1502       G2701730970100            2020          1400000US27173970100
# 1503       G2701730970200            2020          1400000US27173970200
# 1504       G2701730970300            2020          1400000US27173970300
# 1505       G2701730970400            2020          1400000US27173970400
#
#                          GEOCODE              STATE                  COUNTY  \
# 0     Geographic Code Identifier  STATE (FIPS) Name      County (FIPS) Name
# 1                    27001770100          Minnesota           Aitkin County
# 2                    27001770200          Minnesota           Aitkin County
# 3                    27001770300          Minnesota           Aitkin County
# 4                    27001770401          Minnesota           Aitkin County
# ...                          ...                ...                     ...
# 1501                 27171101300          Minnesota           Wright County
# 1502                 27173970100          Minnesota  Yellow Medicine County
# 1503                 27173970200          Minnesota  Yellow Medicine County
# 1504                 27173970300          Minnesota  Yellow Medicine County
# 1505                 27173970400          Minnesota  Yellow Medicine County
#
#                  COUNTYA           TRACTA U71001 U71002 U71003  \
# 0     County (FIPS) Name  CensusTractCode  Total  Urban  Rural
# 1                      1           770100   2244      0   2244
# 2                      1           770200   2278      0   2278
# 3                      1           770300   3298      0   3298
# 4                      1           770401   1308      0   1308
# ...                  ...              ...    ...    ...    ...
# 1501                 171           101300   5154      0   5154
# 1502                 173           970100   2999      0   2999
# 1503                 173           970200   2362      0   2362
# 1504                 173           970300   2302      0   2302
# 1505                 173           970400   1865      0   1865
#
#       UrbanThreshold  RuralThreshold
# 0     UrbanThreshold  RuralThreshold
# 1                  0             100
# 2                  0             100
# 3                  0             100
# 4                  0             100
# ...              ...             ...
# 1501               0             100
# 1502               0             100
# 1503               0             100
# 1504               0             100
# 1505               0             100
#
# [1506 rows x 13 columns]

# %%
usda_merged_df = df

usda_merged_df
# Out:
#    Unnamed: 0    case_id covid_mn_id                         covid_virus_name  \
# 0           0  555555555   MN8888888  hCoV-19/USA/MN-CDC-IBX############/YYYY
#
#          gisaid_id genbank_id ncbi_bioproject_id ncbi_biosample_id first_name  \
# 0  EPI_ISL_#######       test               test              test       test
#
#   last_name  ... State-County FIPS Code Select State    Select County  \
# 0      test  ...                  27053           MN  Hennepin County
#
#    Total-FIPS-Code  Primary RUCA Code 2010  \
# 0      27053106400                       1
#
#    Secondary RUCA Code, 2010 (see errata) Tract Population, 2010  \
# 0                                       1                  1,821
#
#   Land Area (square miles), 2010  Population Density (per square mile), 2010  \
# 0                            0.2                                    8,860.50
#
#    Urban-or-Rural-USDA-Classification
# 0                               Urban
#
# [1 rows x 39 columns]

# %%
df['census_tract'] = df['census_tract'].astype(str)

# Merge based on different column names
merged_df = pandas.merge(df, census, left_on='census_tract', right_on='GEOCODE', how='left')

#This prevents Unassigned values from being dropped
merged_df['GEOCODE'].fillna(value='Unassigned', inplace=True)

#This removes NaN values
merged_df.replace(np.nan, '', inplace=True)

merged_df
# Out:
#    Unnamed: 0    case_id covid_mn_id                         covid_virus_name  \
# 0           0  555555555   MN8888888  hCoV-19/USA/MN-CDC-IBX############/YYYY
#
#          gisaid_id genbank_id ncbi_bioproject_id ncbi_biosample_id first_name  \
# 0  EPI_ISL_#######       test               test              test       test
#
#   last_name  ...      GEOCODE      STATE           COUNTY  COUNTYA  TRACTA  \
# 0      test  ...  27053106400  Minnesota  Hennepin County       53  106400
#
#    U71001 U71002 U71003  UrbanThreshold  RuralThreshold
# 0    1817   1817      0             100               0
#
# [1 rows x 52 columns]

# %%
merged_df.to_csv('MN-Combined-Assigned-Metadata.csv')

# %%
# This creates a new column that vaugly categorizes urban or rural based on Census data

file_path = 'MN-Combined-Assigned-Metadata.csv'
df = pandas.read_csv(file_path)

df['Urban-or-Rural-Census-Classification'] = ''

# Define conditions and update the 'Urban_or_Rural' column
df.loc[(df['UrbanThreshold'] > 50) & (df['RuralThreshold'] < 50), 'Urban-or-Rural-Census-Classification'] = 'Urban'
df.loc[(df['RuralThreshold'] > 50) & (df['UrbanThreshold'] < 50), 'Urban-or-Rural-Census-Classification'] = 'Rural'

#This removes NaN values
df = df.replace(np.nan, '')

# Save the modified DataFrame back to the CSV file
df.to_csv(file_path, index=False)

df
# Out:
#    Unnamed: 0.1  Unnamed: 0    case_id covid_mn_id  \
# 0             0           0  555555555   MN8888888
#
#                           covid_virus_name        gisaid_id genbank_id  \
# 0  hCoV-19/USA/MN-CDC-IBX############/YYYY  EPI_ISL_#######       test
#
#   ncbi_bioproject_id ncbi_biosample_id first_name  ...      STATE  \
# 0               test              test       test  ...  Minnesota
#
#             COUNTY COUNTYA  TRACTA  U71001  U71002  U71003 UrbanThreshold  \
# 0  Hennepin County      53  106400    1817    1817       0            100
#
#   RuralThreshold  Urban-or-Rural-Census-Classification
# 0              0                                 Urban
#
# [1 rows x 54 columns]

# %%
# Further clean up column headers, removing spaces and other punctuation 
df.columns = df.columns.str.replace(r'[\(\)]', '').str.replace(r'[\s\W]', '_', regex=True)
# Further clean up column headers, removing spaces and other punctuation 
df = df.rename(columns={'Secondary RUCA Code, 2010 (see errata)': 'Secondary RUCA Code 2010', 
                        'Land Area (square miles), 2010' : 'Land Area sq miles 2010', 
                        'Population Density (per square mile), 2010' : 'Pop Density per sq mile 2010'
                       })
df.columns = df.columns.str.replace(r'[\(\)]', '').str.replace(r'[\s\W]', '_', regex=True)

df
# Out:
#    Unnamed__0_1  Unnamed__0    case_id covid_mn_id  \
# 0             0           0  555555555   MN8888888
#
#                           covid_virus_name        gisaid_id genbank_id  \
# 0  hCoV-19/USA/MN-CDC-IBX############/YYYY  EPI_ISL_#######       test
#
#   ncbi_bioproject_id ncbi_biosample_id first_name  ...      STATE  \
# 0               test              test       test  ...  Minnesota
#
#             COUNTY COUNTYA  TRACTA  U71001  U71002  U71003 UrbanThreshold  \
# 0  Hennepin County      53  106400    1817    1817       0            100
#
#   RuralThreshold  Urban_or_Rural_Census_Classification
# 0              0                                 Urban
#
# [1 rows x 54 columns]
